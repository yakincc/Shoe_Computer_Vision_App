# %%
import sqlite3
import pandas as pd
import numpy as np
import csv

conn = sqlite3.connect('database.db')
cursor = conn.cursor()

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv(r'https://query.data.world/s/44sfwttfnhuh6cqquxegcvz3jbnb5v?dws=00000')
df.to_sql('women_shoe_data', conn, if_exists='replace', index=False)
df = pd.read_csv(r'C:\Users\yakin\Downloads\7004_1.csv', encoding='latin1')
df.to_sql('men_shoe_data', conn, if_exists='replace', index=False)
# Out:
# C:\Users\yakin\AppData\Local\Temp\ipykernel_17400\3197539192.py:1: DtypeWarning: Columns (25,36,39,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'https://query.data.world/s/44sfwttfnhuh6cqquxegcvz3jbnb5v?dws=00000')
# C:\Users\yakin\AppData\Local\Temp\ipykernel_17400\3197539192.py:3: DtypeWarning: Columns (39,45,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\yakin\Downloads\7004_1.csv', encoding='latin1')
# 19387

# %%
# Display the database contents as a table using pandas
query = "SELECT * FROM men_shoe_data "
result = pd.read_sql_query(query, conn)
result.head()
# Out:
#                      id asins                brand                                  categories colors count             dateAdded           dateUpdated                                       descriptions dimension           ean                                           features flavors                                          imageURLs  isbn                                          keys manufacturer manufacturerNumber                                          merchants                                               name prices.amountMin prices.amountMax prices.availability prices.color prices.condition prices.count prices.currency      prices.dateAdded       prices.dateSeen prices.flavor prices.isSale               prices.merchant       prices.offer prices.returnPolicy prices.shipping prices.size prices.source                                  prices.sourceURLs prices.warranty quantities reviews sizes  skus                                         sourceURLs          upc   vin websiteIDs 
# ...

# %%
# Display the database contents as a table using pandas
query = "SELECT * FROM men_shoe_data WHERE 'Unnamed: 48' IS NOT NULL;"
result = pd.read_sql_query(query, conn)
result
# Out:
#                          id asins                brand                                         categories colors count             dateAdded           dateUpdated                                       descriptions           dimension           ean                                           features flavors                                          imageURLs  isbn                                               keys manufacturer manufacturerNumber                                          merchants                                               name prices.amountMin prices.amountMax prices.availability prices.color prices.condition prices.count prices.currency      prices.dateAdded       prices.dateSeen prices.flavor prices.isSale                   prices.merchant       prices.offer prices.returnPolicy prices.shipping prices.size prices.source                                  prices.sourceURLs prices.warranty quantities reviews sizes                                               skus  \
# ...
